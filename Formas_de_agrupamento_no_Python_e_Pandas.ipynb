# %% [markdown]
# <a href="https://colab.research.google.com/github/DataEtnos/estudos_python/blob/main/Formas_de_agrupamento_no_Python_e_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

import plotly.express as px

from sklearn import datasets
from sklearn.preprocessing import scale, minmax_scale, power_transform

from IPython.core.display import HTML
from ipywidgets import interact, widgets

# %%
sns.set_theme(
    context='talk',
    style='ticks',
    font_scale=.8,
    rc={
        'figure.figsize': (12,8)
    }
)

# %%
#função pra deixar as tabelas na mesma linha (lado a lado)
def display_side_by_side(dataframes:list,titles:list):
    html_str=''
    for df,title in zip(dataframes, titles):
        html_str+=f'<span>{title}:</span>'
        html_str+=df.to_html().replace('table','table style="display:inline"')
        html_str+="&nbsp"*10
    display(HTML(html_str))

# %%
#Data frame para mesclar

df1 = pd.DataFrame(
    {
        "key": ["K0", "K1", "K2", "K3"],
        "A": ["A0", "A1", "A2", "A3"],
        "B": ["B0", "B1", "B2", "B3"],
    }, index=range(4)
)

df2 = pd.DataFrame(
    {
        "key": ["K1", "K2", "K3", "K4"],
        "C": ["C1", "C2", "C3", "C4"],
        "D": ["D1", "D2", "D3", "D4"],
    }, index=range(1,5)
)

df3 = pd.DataFrame(
    {
        "key": ["K1", "K2", "K3", "K4"],
        "E": ["E1", "E2", "E3", "E4"],
        "F": ["F1", "F2", "F3", "F4"],
    }, index=range(1,5)
)

# %%
#lado a lado cada data frame
display_side_by_side([df1,df2, df3], ['df1','df2', 'df3'])
# Out:
# <span>df1:</span><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>key</th>
#       <th>A</th>
#       <th>B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>K0</td>
#       <td>A0</td>
#       <td>B0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>K1</td>
#       <td>A1</td>
#       <td>B1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>K2</td>
#       <td>A2</td>
#       <td>B2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>K3</td>
#       <td>A3</td>
#       <td>B3</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp<span>df2:</span><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>key</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>K1</td>
#       <td>C1</td>
#       <td>D1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>K2</td>
#       <td>C2</td>
#       <td>D2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>K3</td>
#       <td>C3</td>
#       <td>D3</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>K4</td>
#       <td>C4</td>
#       <td>D4</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp<span>df3:</span><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>key</th>
#       <th>E</th>
#       <th>F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>K1</td>
#       <td>E1</td>
#       <td>F1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>K2</td>
#       <td>E2</td>
#       <td>F2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>K3</td>
#       <td>E3</td>
#       <td>F3</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>K4</td>
#       <td>E4</td>
#       <td>F4</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp

# %%
# Agrupando pelo metodo merge para mostrar sua  funções de inner , left e right - joins)
df_inner = df1.merge(df2, on='key', how='inner') #mantém todas as categorias em comum nos dois df
df_left = df1.merge(df2, on='key', how='left') #mantém todas as categorias existentes na coluna da esquerda
df_right = df1.merge(df2, on='key', how='right') #mantém todas as categorias existentes na coluna da direita


#Função de mostrar tabela -> display_side_by_side([lista = formato string])

display_side_by_side(
    dataframes=[df1, df2, df_inner, df_left, df_right],
    titles=['df1', 'df2', 'inner_merge', 'left_merge', 'right_merge'])
# Out:
# <span>df1:</span><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>key</th>
#       <th>A</th>
#       <th>B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>K0</td>
#       <td>A0</td>
#       <td>B0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>K1</td>
#       <td>A1</td>
#       <td>B1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>K2</td>
#       <td>A2</td>
#       <td>B2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>K3</td>
#       <td>A3</td>
#       <td>B3</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp<span>df2:</span><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>key</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>K1</td>
#       <td>C1</td>
#       <td>D1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>K2</td>
#       <td>C2</td>
#       <td>D2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>K3</td>
#       <td>C3</td>
#       <td>D3</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>K4</td>
#       <td>C4</td>
#       <td>D4</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp<span>inner_merge:</span><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>key</th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>K1</td>
#       <td>A1</td>
#       <td>B1</td>
#       <td>C1</td>
#       <td>D1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>K2</td>
#       <td>A2</td>
#       <td>B2</td>
#       <td>C2</td>
#       <td>D2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>K3</td>
#       <td>A3</td>
#       <td>B3</td>
#       <td>C3</td>
#       <td>D3</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp<span>left_merge:</span><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>key</th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>K0</td>
#       <td>A0</td>
#       <td>B0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>K1</td>
#       <td>A1</td>
#       <td>B1</td>
#       <td>C1</td>
#       <td>D1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>K2</td>
#       <td>A2</td>
#       <td>B2</td>
#       <td>C2</td>
#       <td>D2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>K3</td>
#       <td>A3</td>
#       <td>B3</td>
#       <td>C3</td>
#       <td>D3</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp<span>right_merge:</span><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>key</th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>K1</td>
#       <td>A1</td>
#       <td>B1</td>
#       <td>C1</td>
#       <td>D1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>K2</td>
#       <td>A2</td>
#       <td>B2</td>
#       <td>C2</td>
#       <td>D2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>K3</td>
#       <td>A3</td>
#       <td>B3</td>
#       <td>C3</td>
#       <td>D3</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>K4</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>C4</td>
#       <td>D4</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp

# %%
#função merge da aula
@interact(method=['inner','left', 'right','outer'])
def merge(method):
  df_merge=df1.merge(df2, how=method)
  display_side_by_side(
      [df1,df2,df_merge],
      ['df1','df2',f'{method}_join']
  )
# Out:
# interactive(children=(Dropdown(description='method', options=('inner', 'left', 'right', 'outer'), value='inner…
